# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix, recall_score, precision_score
import pickle

# %%
df = pd.read_csv("https://raw.githubusercontent.com/evgpat/stepik_from_idea_to_mvp/main/datasets/clients.csv")

# %%
df = df[df['satisfaction'].isin(['neutral or dissatisfied','satisfied'])]

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
features = ['Leg room service',
 'Baggage handling',
 'On-board service',
 'Age',
 'Checkin service',
 'Type of Travel',
 'satisfaction']

# %%
df = df[features]

# %%
df = df.dropna(subset=['Type of Travel'])

# %%
df['Type of Travel'] = df['Type of Travel'].map({'Business travel': 1, 'Personal Travel': 0})

# %%
X = df.drop(['satisfaction'], axis=1)
y = df['satisfaction']

# %%
y = y.map({'satisfied': 1, 'neutral or dissatisfied': 0})

# %%
df['Type of Travel'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
numeric_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
transformer = ColumnTransformer([
    ('numeric', numeric_pipeline, X.columns)
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=25)

# %%
transformer.fit(X_train)

X_train_tranformed = pd.DataFrame(transformer.transform(X_train), columns=X.columns)
X_test_tranformed = pd.DataFrame(transformer.transform(X_test), columns=X.columns)

# %%
model = RandomForestClassifier(n_estimators=50)

# %%
model.fit(X_train_tranformed, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
y_pred = model.predict_proba(X_test_tranformed)

# %%
classes = (y_pred[:, 1] > 0.5).astype(int)

# %%
classes
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
pd.Series(classes).value_counts()
# Out:
# 0    15001
# 1    10953
# Name: count, dtype: int64

# %%
with open('model.pickle', 'wb') as file:
    pickle.dump(model, file)

# %%
with open('transformer.pickle', 'wb') as f:
    pickle.dump(transformer, f)

# %%
data = {
        'Leg room service': 0,
        'Baggage handling': 10,
        'On-board service': 0,
        'Age': 10,
        'Checkin service': 10,
        'Type of Travel': 0
    }

df = pd.DataFrame(data, index=[0])

# %%
pd.DataFrame(model.predict_proba(df), )
# Out:
#      0    1
# 0  0.2  0.8

# %%
X_test['classes'] = classes

# %%
X_test
# Out:
#         Leg room service  Baggage handling  On-board service   Age  \
# 129341               5.0               3.0               3.0  57.0
# 97478                4.0               4.0               2.0  30.0
# 26931                1.0               2.0               1.0  29.0
# 106605               2.0               2.0               4.0  27.0
# 110042               2.0               2.0               1.0  50.0
# ...                  ...               ...               ...   ...
# 26006                4.0               3.0               2.0  18.0
# 53355                4.0               2.0               2.0  27.0
# 1041                 4.0               4.0               4.0  37.0
# 53170                3.0               3.0               5.0  36.0
# 125997               3.0               5.0               5.0  52.0
#
#         Checkin service  Type of Travel  classes
# 129341              5.0               0        1
# 97478               3.0               1        0
# 26931               2.0               1        1
# 106605              3.0               1        0
# 110042              1.0               1        0
# ...                 ...             ...      ...
# 26006               1.0               1        0
# 53355               2.0               1        0
# 1041                3.0               1        1
# 53170               2.0               1        0
# 125997              4.0               0        0
#
# [25954 rows x 7 columns]
